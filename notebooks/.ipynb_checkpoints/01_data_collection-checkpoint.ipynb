# %% [markdown]
# # BEE2041 Empirical Project: What property and location factors determine Airbnb listing prices in London?
# ## 01_data_collection

# %%
# Import libraries
import pandas as pd
import requests

# %%
# Download Data
url = "https://data.insideairbnb.com/united-kingdom/england/london/2025-09-14/data/listings.csv.gz"

print("Downloading data")

# Load csv
df = pd.read_csv(url, compression="gzip")

# Save locally
df.to_csv("../data/raw/london.csv", index=False)

print("Dataset loaded:", df.shape)
# Out:
# ...
# Dataset loaded: (96871, 79)
