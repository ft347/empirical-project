# %% [markdown]
# # BEE2041 Empirical Project: What drives popularity on Spotify?
# ## Notebook 1: Data Collection

# %%
# Import Libraries
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import time
import random

# %%
# Connect to Spotify API
# Define Client ID & Secret
client_id = "24a563235c154cdea15340c3649ed321"
client_secret = "48118592b8194fd19b2183f9e5976dfc"

# Pass in Client ID & Secret
sp = spotipy.Spotify(
    auth_manager=SpotifyOAuth(
        client_id=client_id,
        client_secret=client_secret,
        redirect_uri="http://127.0.0.1:8080/callback",
        scope="user-library-read"
    )
)

# %%
# Define Parameters
# Set date range to be from 2000-2025
years = list(range(2000, 2026))

# Define genres of music for dataset
genres = [
    "pop",
    "rock",
    "hip-hop",
    "rap",
    "electronic",
    "dance",
    "indie",
    "jazz",
    "classical",
    "country",
    "latin",
    "rnb"
]

# Define letters to randomly search
letters = list("abcdefghijklmnopqrstuvwxyz")

# Create track storage list
tracks = []

results = sp.search(q="pop year:2015", type="track", limit=5, market="GB")

for track in results["tracks"]["items"]:
    print(track["name"], "-", track["artists"][0]["name"])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 27
#      24 # Create track storage list
#      25 tracks = []
# ---> 27 results = sp.search(q="pop year:2015", type="track", limit=5, market="GB")
#      29 for track in results["tracks"]["items"]:
#      30     print(track["name"], "-", track["artists"][0]["name"])
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:613, in Spotify.search(self, q, limit, offset, type, market)
#     598 def search(self, q, limit=10, offset=0, type="track", market=None):
#     599     """ searches for an item
#     600
#     601         Parameters:
#    (...)
#     611                        from_token.
#     612     """
# --> 613     return self._get(
#     614         "search", q=q, limit=limit, offset=offset, type=type, market=market
#     615     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:321, in Spotify._get(self, url, args, payload, **kwargs)
#     318 if args:
#     319     kwargs.update(args)
# --> 321 return self._internal_call("GET", url, payload, kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:247, in Spotify._internal_call(self, method, url, payload, params)
#     245 if not url.startswith("http"):
#     246     url = self.prefix + url
# --> 247 headers = self._auth_headers()
#     249 if "content_type" in args["params"]:
#     250     headers["Content-Type"] = args["params"]["content_type"]
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:238, in Spotify._auth_headers(self)
#     236     return {}
#     237 try:
# --> 238     token = self.auth_manager.get_access_token(as_dict=False)
#     239 except TypeError:
#     240     token = self.auth_manager.get_access_token()
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/oauth2.py:513, in SpotifyOAuth.get_access_token(self, code, as_dict, check_cache)
#     506             token_info = self.refresh_access_token(
#     507                 token_info["refresh_token"]
#     508             )
#     509         return token_info if as_dict else token_info["access_token"]
#     511 payload = {
#     512     "redirect_uri": self.redirect_uri,
# --> 513     "code": code or self.get_auth_response(),
#     514     "grant_type": "authorization_code",
#     515 }
#     516 if self.scope:
#     517     payload["scope"] = self.scope
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/oauth2.py:469, in SpotifyOAuth.get_auth_response(self, open_browser)
#     462 if (
#     463         open_browser
#     464         and redirect_host in ("127.0.0.1", "localhost")
#     465         and redirect_info.scheme == "http"
#     466 ):
#     467     # Only start a local http server if a port is specified
#     468     if redirect_port:
# --> 469         return self._get_auth_response_local_server(redirect_port)
#     470     else:
#     471         logger.warning(f'Using `{redirect_host}` as redirect URI without a port. '
#     472                        f'Specify a port (e.g. `{redirect_host}:8080`) to allow '
#     473                        'automatic retrieval of authentication code '
#     474                        'instead of having to copy and paste '
#     475                        'the URL your browser is redirected to.')
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/oauth2.py:425, in SpotifyOAuth._get_auth_response_local_server(self, redirect_port)
#     424 def _get_auth_response_local_server(self, redirect_port):
# --> 425     server = start_local_http_server(redirect_port)
#     426     self._open_auth_url()
#     427     server.handle_request()
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/oauth2.py:1285, in start_local_http_server(port, handler)
#    1284 def start_local_http_server(port, handler=RequestHandler):
# -> 1285     server = HTTPServer(("127.0.0.1", port), handler)
#    1286     server.allow_reuse_address = True
#    1287     server.auth_code = None
#
# File /opt/anaconda3/lib/python3.12/socketserver.py:457, in TCPServer.__init__(self, server_address, RequestHandlerClass, bind_and_activate)
#     455 if bind_and_activate:
#     456     try:
# --> 457         self.server_bind()
#     458         self.server_activate()
#     459     except:
#
# File /opt/anaconda3/lib/python3.12/http/server.py:136, in HTTPServer.server_bind(self)
#     134 def server_bind(self):
#     135     """Override server_bind to store the server name."""
# --> 136     socketserver.TCPServer.server_bind(self)
#     137     host, port = self.server_address[:2]
#     138     self.server_name = socket.getfqdn(host)
#
# File /opt/anaconda3/lib/python3.12/socketserver.py:473, in TCPServer.server_bind(self)
#     471 if self.allow_reuse_port and hasattr(socket, "SO_REUSEPORT"):
#     472     self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEPORT, 1)
# --> 473 self.socket.bind(self.server_address)
#     474 self.server_address = self.socket.getsockname()
#
# OSError: [Errno 48] Address already in use

# %%
# Collect song data
# Loop through parameters to find songs
tracks = []

for year in years:
    
    for genre in genres:
        
        for offset in range(0, 200, 50):
            
            query = f"{genre} year:{year}"
            
            try:
                
                results = sp.search(
                    q=query,
                    type="track",
                    limit=50,
                    offset=offset,
                    market="GB"
                )
                
                items = results["tracks"]["items"]
                
                if len(items) == 0:
                    continue
                
                for track in items:
                    print(track["name"])
                    
                    tracks.append({
                        "track_name": track["name"],
                        "artist": track["artists"][0]["name"],
                        "artist_id": track["artists"][0]["id"],
                        "track_id": track["id"],
                        "popularity": track["popularity"],
                        "release_date": track["album"]["release_date"],
                        "duration_ms": track["duration_ms"],
                        "explicit": track["explicit"]
                    })
                
                time.sleep(0.2)
            
            except:
                continue

# %%
df_tracks = pd.DataFrame(tracks)

print("Raw tracks collected:", len(df_tracks))
# Out:
# Raw tracks collected: 0
