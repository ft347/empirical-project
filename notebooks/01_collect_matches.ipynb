# %% [markdown]
# # BEE2041 Empirical Project: What predicts match outcomes in the Premier League?
# ## 01_collect_matches

# %%
# Import libraries
import pandas as pd
import requests
from bs4 import BeautifulSoup
